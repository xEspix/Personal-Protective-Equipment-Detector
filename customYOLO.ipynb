# %%
# !nvidia-smi
# Out:
# Fri Oct 25 20:36:41 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   52C    P8              12W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
import zipfile
zip_ref=zipfile.ZipFile('/content/Construction Site Safety.v28-yolov5s.yolov8.zip','r')
zip_ref.extractall('/content')
zip_ref.close()

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 877.6/877.6 kB 36.7 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# !yolo task=detect mode=predict model=yolov8s.pt conf=0.25 source="https://ultralytics.com/images/bus.jpg"
# Out:
# ...
# 100% 21.5M/21.5M [00:00<00:00, 494MB/s]
# Ultralytics 8.3.23 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8s summary (fused): 168 layers, 11,156,544 parameters, 0 gradients, 28.6 GFLOPs
#
# ...
# 100% 134k/134k [00:00<00:00, 29.7MB/s]
# image 1/1 /content/bus.jpg: 640x480 4 persons, 1 bus, 84.1ms
# Speed: 12.1ms preprocess, 84.1ms inference, 1524.3ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task=detect mode=train model=yolov8s.pt conf=0.25 data=../content/ConstructionSafety/data.yaml epochs=50 imgsz=640
# Out:
# Ultralytics 8.3.23 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
